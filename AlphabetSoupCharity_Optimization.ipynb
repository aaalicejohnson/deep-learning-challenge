# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("Resources/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df.drop(["EIN", "NAME"], axis=1, inplace=True)
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
cutoff = 156
application_type_value_counts = application_df["APPLICATION_TYPE"].value_counts()
application_types_to_replace = list(application_type_value_counts[application_type_value_counts <= cutoff].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
classification_values = application_df["CLASSIFICATION"].value_counts()
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
cutoff = 777
classifications_to_replace = list(classification_values[classification_values <= cutoff].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# print(application_df.nunique())

# %%
# print(application_df["STATUS"].value_counts())
# Out:
# 1    34294
# 0        5
# Name: STATUS, dtype: int64

# %%
# print(application_df["SPECIAL_CONSIDERATIONS"].value_counts())
# Out:
# N    34272
# Y       27
# Name: SPECIAL_CONSIDERATIONS, dtype: int64

# %%
# application_df.drop(['STATUS', "SPECIAL_CONSIDERATIONS"], axis=1, inplace=True)
# application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION     INCOME_AMT  ASK_AMT  IS_SUCCESSFUL
# 0   Association              0     5000              1
# 1  Co-operative         1-9999   108590              1
# 2   Association              0     5000              0
# 3         Trust    10000-24999     6692              1
# 4         Trust  100000-499999   142590              1

# %%
# print(application_df["AFFILIATION"].value_counts())
# Out:
# Independent         18480
# CompanySponsored    15705
# Family/Parent          64
# National               33
# Regional               13
# Other                   4
# Name: AFFILIATION, dtype: int64

# %%
# # Choose a cutoff value and create a list of affiliation types to be replaced

# cutoff = 64
# aff_value_counts = application_df['AFFILIATION'].value_counts()
# aff_to_replace = list(aff_value_counts[aff_value_counts <= cutoff].index)

# # Replace in dataframe
# for aff in aff_to_replace:
#     application_df['AFFILIATION'] = application_df['AFFILIATION'].replace(aff,"Other")

# # Check to make sure binning was successful
# application_df['AFFILIATION'].value_counts()
# Out:
# Independent         18480
# CompanySponsored    15705
# Other                 114
# Name: AFFILIATION, dtype: int64

# %%
X_dummies = pd.get_dummies(application_df)
X_dummies
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0           1      5000              1                       0
# 1           1    108590              1                       0
# 2           1      5000              0                       0
# 3           1      6692              1                       0
# 4           1    142590              1                       0
# ...       ...       ...            ...                     ...
# 34294       1      5000              0                       0
# 34295       1      5000              0                       0
# 34296       1      5000              0                       0
# 34297       1      5000              1                       0
# 34298       1  36500179              0                       0
#
#        APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                         1                     0                    0
# ...

# %%
# Split our preprocessed data into our features and target arrays
X = X_dummies.drop('IS_SUCCESSFUL',axis=1).values
y = application_df['IS_SUCCESSFUL'].values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# #Attempt 1: Changing Nodes, Layers, and Activations

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
input_features = len(X_train[0])
node1 =  100
node2 = 40
node3 = 20

nn = tf.keras.models.Sequential()
# First hidden layer
nn.add(tf.keras.layers.Dense(node1, activation="relu", input_dim=input_features))
# Second hidden layer
nn.add(tf.keras.layers.Dense(units=node2, activation="sigmoid"))
# third hidden layer
nn.add(tf.keras.layers.Dense(units=node3, activation="sigmoid"))
# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))
# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 100)               4400
#
#  dense_1 (Dense)             (None, 40)                4040
#
#  dense_2 (Dense)             (None, 20)                820
#
#  dense_3 (Dense)             (None, 1)                 21
#
# ...
# Total params: 9,281
# Trainable params: 9,281
# Non-trainable params: 0
# _________________________________________________________________

# %%
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
fit_model = nn.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 3s 2ms/step - loss: 0.5798 - accuracy: 0.7149
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5576 - accuracy: 0.7295
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5540 - accuracy: 0.7295
# Epoch 4/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5518 - accuracy: 0.7303
# Epoch 5/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5512 - accuracy: 0.7312
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5500 - accuracy: 0.7327
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5489 - accuracy: 0.7327
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5479 - accuracy: 0.7323
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5473 - accuracy: 0.7325
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5674 - accuracy: 0.7278 - 545ms/epoch - 2ms/step
# Loss: 0.5673794150352478, Accuracy: 0.7278134226799011

# %% [markdown]
# #Attempt 2: Changing Nodes and Activations

# %%
input_features = len(X_train[0])
node1 =  100
node2 = 80
node3 = 30
node4 = 10

nn_new = tf.keras.models.Sequential()
# First hidden layer
nn_new.add(tf.keras.layers.Dense(node1, activation="relu", input_dim=input_features))
# Second hidden layer
nn_new.add(tf.keras.layers.Dense(units=node2, activation="relu", input_dim=input_features))
# third hidden layer
nn_new.add(tf.keras.layers.Dense(units=node3, activation="relu", input_dim=input_features))
# fourth hidden layer
nn_new.add(tf.keras.layers.Dense(units=node4, activation="relu", input_dim=input_features))
# Output layer
nn_new.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))
# Check the structure of the model
nn_new.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_13 (Dense)            (None, 100)               4400
#
#  dense_14 (Dense)            (None, 80)                8080
#
#  dense_15 (Dense)            (None, 30)                2430
#
#  dense_16 (Dense)            (None, 10)                310
#
#  dense_17 (Dense)            (None, 1)                 11
#
# ...
# Total params: 15,231
# Trainable params: 15,231
# Non-trainable params: 0
# _________________________________________________________________

# %%
nn_new.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
fit_model = nn_new.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 4s 2ms/step - loss: 0.5704 - accuracy: 0.7207
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5552 - accuracy: 0.7290
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5513 - accuracy: 0.7302
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5503 - accuracy: 0.7306
# Epoch 5/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5491 - accuracy: 0.7326
# Epoch 6/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5482 - accuracy: 0.7325
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5472 - accuracy: 0.7332
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5466 - accuracy: 0.7337
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5458 - accuracy: 0.7343
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5674 - accuracy: 0.7278 - 698ms/epoch - 3ms/step
# Loss: 0.5673794150352478, Accuracy: 0.7278134226799011

# %% [markdown]
# # Attempt 3: Processing changes

# %%
application_df = pd.read_csv("Resources/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
cutoff = 156
application_type_value_counts = application_df["APPLICATION_TYPE"].value_counts()
application_types_to_replace = list(application_type_value_counts[application_type_value_counts <= cutoff].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
classification_values = application_df["CLASSIFICATION"].value_counts()
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
cutoff = 777
classifications_to_replace = list(classification_values[classification_values <= cutoff].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
print(application_df.nunique())
# Out:
# EIN                       34299
# NAME                      19568
# APPLICATION_TYPE              9
# AFFILIATION                   6
# CLASSIFICATION                6
# USE_CASE                      5
# ORGANIZATION                  4
# STATUS                        2
# INCOME_AMT                    9
# SPECIAL_CONSIDERATIONS        2
# ASK_AMT                    8747
# IS_SUCCESSFUL                 2
# dtype: int64

# %%
print(application_df["NAME"].value_counts() )
# Out:
# PARENT BOOSTER USA INC                                                  1260
# TOPS CLUB INC                                                            765
# UNITED STATES BOWLING CONGRESS INC                                       700
# WASHINGTON STATE UNIVERSITY                                              492
# AMATEUR ATHLETIC UNION OF THE UNITED STATES INC                          408
#                                                                         ...
# ST LOUIS SLAM WOMENS FOOTBALL                                              1
# AIESEC ALUMNI IBEROAMERICA CORP                                            1
# WEALLBLEEDRED ORG INC                                                      1
# AMERICAN SOCIETY FOR STANDARDS IN MEDIUMSHIP & PSYCHICAL INVESTIGATI       1
# WATERHOUSE CHARITABLE TR                                                   1
# Name: NAME, Length: 19568, dtype: int64

# %%
name_values = application_df["NAME"].value_counts()
name_value_counts = name_values[name_values > 10]
name_value_counts
# Out:
# PARENT BOOSTER USA INC                                                    1260
# TOPS CLUB INC                                                              765
# UNITED STATES BOWLING CONGRESS INC                                         700
# WASHINGTON STATE UNIVERSITY                                                492
# AMATEUR ATHLETIC UNION OF THE UNITED STATES INC                            408
#                                                                           ...
# USA SWIMMING INC                                                            11
# SIGMA ALPHA OMEGA CHRISTIAN SORORITY INC                                    11
# SOCIETY FOR PRESERVATION & ENCOURMT OF BARBERSHOP QUARTET SINGING AMER      11
# SONS OF ITALY IN AMERICA                                                    11
# FELLOWSHIP OF CHRISTIAN COWBOYS INC                                         11
# Name: NAME, Length: 204, dtype: int64

# %%
cutoff = 10
name_to_replace = list(name_values[name_values <= cutoff].index)

# Replace in dataframe
for name in name_to_replace :
  application_df['NAME'] = application_df['NAME'].replace(name,"Other")
# Check to make sure binning was successful
application_df['NAME'].value_counts()
# Out:
# Other                                                                     21202
# PARENT BOOSTER USA INC                                                     1260
# TOPS CLUB INC                                                               765
# UNITED STATES BOWLING CONGRESS INC                                          700
# WASHINGTON STATE UNIVERSITY                                                 492
#                                                                           ...
# AMERICAN POSTAL WORKERS UNION                                                11
# SOCIETY FOR PRESERVATION & ENCOURMT OF BARBERSHOP QUARTET SINGING AMER       11
# SIGMA ALPHA OMEGA CHRISTIAN SORORITY INC                                     11
# FINANCIAL PLANNING ASSOCIATION                                               11
# SLOW FOOD U S A INC                                                          11
# Name: NAME, Length: 205, dtype: int64

# %%
application_df.drop(["EIN"], axis=1, inplace=True)
application_df.head()
# Out:
#     NAME APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0  Other              T10       Independent          C1000    ProductDev
# 1  Other               T3       Independent          C2000  Preservation
# 2  Other               T5  CompanySponsored          C3000    ProductDev
# 3  Other               T3  CompanySponsored          C2000  Preservation
# 4  Other               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# ...

# %%
application_df['SPECIAL_CONSIDERATIONS'].value_counts()
# Out:
# N    34272
# Y       27
# Name: SPECIAL_CONSIDERATIONS, dtype: int64

# %%
application_df['STATUS'].value_counts()
# Out:
# 1    34294
# 0        5
# Name: STATUS, dtype: int64

# %%
application_df.drop(["SPECIAL_CONSIDERATIONS", "STATUS"], axis=1, inplace=True)
application_df.head()
# Out:
#     NAME APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0  Other              T10       Independent          C1000    ProductDev
# 1  Other               T3       Independent          C2000  Preservation
# 2  Other               T5  CompanySponsored          C3000    ProductDev
# 3  Other               T3  CompanySponsored          C2000  Preservation
# 4  Other               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION     INCOME_AMT  ASK_AMT  IS_SUCCESSFUL
# 0   Association              0     5000              1
# 1  Co-operative         1-9999   108590              1
# 2   Association              0     5000              0
# 3         Trust    10000-24999     6692              1
# 4         Trust  100000-499999   142590              1

# %%
X_dummies = pd.get_dummies(application_df)
len(X_dummies.columns)
# Out:
# 246

# %%
# Split our preprocessed data into our features and target arrays
y = application_df['IS_SUCCESSFUL'].values
X = X_dummies.drop('IS_SUCCESSFUL',axis=1).values
# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
len(X_train_scaled[0])
# Out:
# 245

# %%
input_features = len(X_train_scaled[0])
nodes1 = 100
nodes2 = 30 
nodes3 = 20
nodes4 = 1

nn_model = tf.keras.models.Sequential()

# First hidden layer
nn_model.add(tf.keras.layers.Dense(units=nodes1, activation="relu", input_dim=input_features))

# Second hidden layer
nn_model.add(tf.keras.layers.Dense(units=nodes2, activation="relu", input_dim=input_features))

# Third hidden layer
nn_model.add(tf.keras.layers.Dense(units=nodes3, activation="relu", input_dim=input_features))

# Output layer
nn_model.add(tf.keras.layers.Dense(units=nodes4, activation="sigmoid"))

# Check the structure of the model
nn_model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_18 (Dense)            (None, 100)               24600
#
#  dense_19 (Dense)            (None, 30)                3030
#
#  dense_20 (Dense)            (None, 20)                620
#
#  dense_21 (Dense)            (None, 1)                 21
#
# ...
# Total params: 28,271
# Trainable params: 28,271
# Non-trainable params: 0
# _________________________________________________________________

# %%
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
fit_model = nn_model.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 5s 2ms/step - loss: 0.4791 - accuracy: 0.7691
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4453 - accuracy: 0.7835
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4404 - accuracy: 0.7863
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4396 - accuracy: 0.7863
# Epoch 5/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4376 - accuracy: 0.7890
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4365 - accuracy: 0.7883
# Epoch 7/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.4356 - accuracy: 0.7891
# Epoch 8/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4346 - accuracy: 0.7906
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4340 - accuracy: 0.7898
# Epoch 10/100
# ...

# %%
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.4971 - accuracy: 0.7795 - 1s/epoch - 5ms/step
# Loss: 0.49707236886024475, Accuracy: 0.779475212097168

# %%
nn_model.save('AlphabetSoupCharity_Optimization.h5')
